# %% [markdown]
# <a href="https://colab.research.google.com/github/andrew-yian-sun/Data-Analysis-Tools/blob/main/QSIprep_ImageQCs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import google.colab.drive as drive

# %%
drive.mount('/content/g')
# Out:
# Mounted at /content/g

# %%
imageQC_file_aggregate = pd.read_csv('/content/g/MyDrive/LANI/qsiprep/sub-ALL_ses-1_dir-AP_desc-ImageQC_dwi.csv')

# %%
imageQC_file_aggregate
# Out:
#     raw_dimension_x  raw_dimension_y  raw_dimension_z  raw_voxel_size_x  \
# 0             204.0            176.0             64.0           0.95098
# 1             204.0            176.0             64.0           0.95098
# 2             204.0            176.0             64.0           0.95098
# 3             204.0            176.0             64.0           0.95098
# 4             204.0            176.0             64.0           0.95098
# 5             204.0            176.0             64.0           0.95098
# 6             204.0            176.0             64.0           0.95098
# 7             204.0            176.0             64.0           0.95098
# 8             204.0            176.0             64.0           0.95098
# 9             204.0            176.0             64.0           0.95098
# 10            204.0            176.0             64.0           0.95098
# 11            204.0            176.0             64.0           0.95098
# ...

# %%
for column in imageQC_file_aggregate.columns:
  # print(column)
  # px.strip(imageQC_file_aggregate[column], x=column)

# %%
px.strip(imageQC_file_aggregate, x="mean_fd", hover_name="subject_id")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
